# %%
# roberta-yaclc-fluency_testA
para = open("./roberta/yaclc-fluency_testA.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./roberta/yaclc-fluency_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta/yaclc-fluency_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# bert-yaclc-fluency_testA
para = open("./bert/yaclc-fluency_testA.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./bert/yaclc-fluency_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./bert/yaclc-fluency_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# rbt6-yaclc-fluency_testA
para = open("./rbt6/yaclc-fluency_testA.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./rbt6/yaclc-fluency_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./rbt6/yaclc-fluency_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# macbert-yaclc-fluency_testA
para = open("./macbert/yaclc-fluency_testA.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./macbert/yaclc-fluency_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./macbert/yaclc-fluency_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# macbert-yaclc-fluency_testA
para = open("./roberta-large-14/yaclc-fluency_testA.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./roberta-large-14/yaclc-fluency_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta-large-14/yaclc-fluency_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# roberta+rbt6+bert-yaclc-fluency_testA
para = open("./roberta+rbt6+bert/yaclc-fluency_testA_roberta_bert_rbt6.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./roberta+rbt6+bert/yaclc-fluency_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta+rbt6+bert/yaclc-fluency_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# roberta+bert+macbert-yaclc-fluency_testA
para = open("./roberta+bert+macbert/yaclc-fluency_testA_roberta_bert_macbert.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./roberta+bert+macbert/yaclc-fluency_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta+bert+macbert/yaclc-fluency_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# roberta+rbt6+bert+macbert-yaclc-fluency_testA
para = open("./roberta+rbt6+bert+macbert/yaclc-fluency_testA_roberta_bert_rbt6_macbert.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./roberta+rbt6+bert+macbert/yaclc-fluency_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta+rbt6+bert+macbert/yaclc-fluency_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# yaclc-fluency_testA ensemble
# !python ../ensemble.py \
--source_file ./roberta/yaclc-fluency_testA.src \
--target_files ./roberta/yaclc-fluency_testA.tgt ./roberta-large-14/yaclc-fluency_testA.tgt  \
--output_file yaclc-fluency_testA.preds

para = []
s = open("./roberta/yaclc-fluency_testA.src","r").readlines()
t = open("./yaclc-fluency_testA.preds","r").readlines()
output = open("./yaclc-fluency_testA.para","w")
for line in range(len(s)):
    s[line]=''.join(s[line].split())
    s[line]=s[line].lstrip(str(line))
    t[line]=''.join(t[line].split())
    t[line]=t[line].lstrip(str(line))
    para.append(str(line)+"\t"+s[line].strip("\n")+"\t"+t[line].strip("\n")+"\n")
    
    
[output.write(str(item)) for item in para]
output.close()
# Out:
# 2022-08-24 09:59:38.855398: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-08-24 09:59:38.855508: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-08-24 09:59:38.855524: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# roberta-yaclc-minimal_testA
para = open("./roberta/yaclc-minimal_testA.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./roberta/yaclc-minimal_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta/yaclc-minimal_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# bert-yaclc-minimal_testA
para = open("./bert/yaclc-minimal_testA.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./bert/yaclc-minimal_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./bert/yaclc-minimal_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# rbt6-yaclc-minimal_testA
para = open("./rbt6/yaclc-minimal_testA.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./rbt6/yaclc-minimal_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./rbt6/yaclc-minimal_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# macbert-yaclc-minimal_testA
para = open("./macbert/yaclc-minimal_testA.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    # print(line[0])
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./macbert/yaclc-minimal_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()
t = open("./macbert/yaclc-minimal_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# macbert-yaclc-minimal_testA
para = open("./roberta-large-14/yaclc-minimal_testA.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    # print(line[0])
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./roberta-large-14/yaclc-minimal_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()
t = open("./roberta-large-14/yaclc-minimal_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# roberta+rbt6+bert-yaclc-minimal_testA
para = open("./roberta+rbt6+bert/yaclc-minimal_testA_roberta_bert_rbt6.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./roberta+rbt6+bert/yaclc-minimal_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta+rbt6+bert/yaclc-minimal_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# roberta+bert+macbert-yaclc-minimal_testA
para = open("./roberta+bert+macbert/yaclc-minimal_testA_roberta_bert_macbert.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./roberta+bert+macbert/yaclc-minimal_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta+bert+macbert/yaclc-minimal_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# roberta+rbt6+bert+macbert-yaclc-minimal_testA
para = open("./roberta+rbt6+bert+macbert/yaclc-minimal_testA_roberta_bert_rbt6_macbert.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./roberta+rbt6+bert+macbert/yaclc-minimal_testA.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta+rbt6+bert+macbert/yaclc-minimal_testA.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# yaclc-minimal_testA ensemble
# !python ../ensemble.py \
--source_file ./roberta/yaclc-minimal_testA.src \
--target_files ./roberta/yaclc-minimal_testA.tgt ./roberta-large-14/yaclc-minimal_testA.tgt  \
--output_file yaclc-minimal_testA.preds

para = []
s = open("./roberta/yaclc-minimal_testA.src","r").readlines()
t = open("./yaclc-minimal_testA.preds","r").readlines()
output = open("./yaclc-minimal_testA.para","w")
for line in range(len(s)):
    s[line]=''.join(s[line].split())
    s[line]=s[line].lstrip(str(line))
    t[line]=''.join(t[line].split())
    t[line]=t[line].lstrip(str(line))
    para.append(str(line)+"\t"+s[line].strip("\n")+"\t"+t[line].strip("\n")+"\n")
    
    
[output.write(str(item)) for item in para]
output.close()
# Out:
# 2022-08-24 10:05:41.990632: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-08-24 10:05:41.990841: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-08-24 10:05:41.990869: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# roberta-yaclc-minimal_testB
para = open("./roberta/yaclc-minimal_testB.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./roberta/yaclc-minimal_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta/yaclc-minimal_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# bert-yaclc-minimal_testB
para = open("./bert/yaclc-minimal_testB.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./bert/yaclc-minimal_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./bert/yaclc-minimal_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# rbt6-yaclc-minimal_testB
para = open("./rbt6/yaclc-minimal_testB.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./rbt6/yaclc-minimal_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./rbt6/yaclc-minimal_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# macbert-yaclc-minimal_testB
para = open("./macbert/yaclc-minimal_testB.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./macbert/yaclc-minimal_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./macbert/yaclc-minimal_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# macbert-yaclc-minimal_testB
para = open("./roberta-large-14/yaclc-minimal_testB.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./roberta-large-14/yaclc-minimal_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta-large-14/yaclc-minimal_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# macbert-yaclc-minimal_testB
para = open("./roberta_large_19/yaclc-minimal_testB.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./roberta_large_19/yaclc-minimal_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta_large_19/yaclc-minimal_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# roberta+rbt6+bert-yaclc-minimal_testB
para = open("./roberta+rbt6+bert/yaclc-minimal_testB_roberta_bert_rbt6.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./roberta+rbt6+bert/yaclc-minimal_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta+rbt6+bert/yaclc-minimal_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# roberta+bert+macbert-yaclc-minimal_testB
para = open("./roberta+bert+macbert/yaclc-minimal_testB_roberta_bert_macbert.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./roberta+bert+macbert/yaclc-minimal_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta+bert+macbert/yaclc-minimal_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# roberta+rbt6+bert+macbert-yaclc-minimal_testB
para = open("./roberta+rbt6+bert+macbert/yaclc-minimal_testB_roberta_bert_rbt6_macbert.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./roberta+rbt6+bert+macbert/yaclc-minimal_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta+rbt6+bert+macbert/yaclc-minimal_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# yaclc-minimal_testB ensemble
# !python ../ensemble.py \
--source_file ./roberta/yaclc-minimal_testB.src \
--target_files ./roberta/yaclc-minimal_testB.tgt ./bert/yaclc-minimal_testB.tgt ./roberta_large_19/yaclc-minimal_testB.tgt  \
--output_file yaclc-minimal_testB.preds

para = []
s = open("./roberta/yaclc-minimal_testB.src","r").readlines()
t = open("./yaclc-minimal_testB.preds","r").readlines()
output = open("./yaclc-minimal_testB.para","w")
for line in range(len(s)):
    s[line]=''.join(s[line].split())
    s[line]=s[line].lstrip(str(line))
    t[line]=''.join(t[line].split())
    t[line]=t[line].lstrip(str(line))
    para.append(str(line)+"\t"+s[line].strip("\n")+"\t"+t[line].strip("\n")+"\n")
    
    
[output.write(str(item)) for item in para]
output.close()
# Out:
# 2022-08-25 21:02:04.719798: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-08-25 21:02:04.719930: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-08-25 21:02:04.719947: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# roberta-yaclc-fluency_testB
para = open("./roberta/yaclc-fluency_testB.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./roberta/yaclc-fluency_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta/yaclc-fluency_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()
# Out:
# 2022-08-20 11:23:09.558549: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-08-20 11:23:09.558720: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-08-20 11:23:09.558741: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# bert-yaclc-fluency_testB
para = open("./bert/yaclc-fluency_testB.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./bert/yaclc-fluency_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./bert/yaclc-fluency_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# rbt6-yaclc-fluency_testB
para = open("./rbt6/yaclc-fluency_testB.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./rbt6/yaclc-fluency_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./rbt6/yaclc-fluency_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# macbert-yaclc-fluency_testB
para = open("./macbert/yaclc-fluency_testB.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./macbert/yaclc-fluency_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./macbert/yaclc-fluency_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# macbert-yaclc-fluency_testB
para = open("./roberta-large-14/yaclc-fluency_testB.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./roberta-large-14/yaclc-fluency_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta-large-14/yaclc-fluency_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# macbert-yaclc-fluency_testB
para = open("./roberta_large_19/yaclc-fluency_testB.para","r").readlines()
src = []
tgt = []
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    tgt.append(' '.join(line[2]))

s = open("./roberta_large_19/yaclc-fluency_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta_large_19/yaclc-fluency_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# roberta+rbt6+bert-yaclc-fluency_testB
para = open("./roberta+rbt6+bert/yaclc-fluency_testB_roberta_bert_rbt6.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./roberta+rbt6+bert/yaclc-fluency_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta+rbt6+bert/yaclc-fluency_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# roberta+bert+macbert-yaclc-fluency_testB
para = open("./roberta+bert+macbert/yaclc-fluency_testB_roberta_bert_macbert.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./roberta+bert+macbert/yaclc-fluency_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta+bert+macbert/yaclc-fluency_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# roberta+rbt6+bert+macbert-yaclc-fluency_testB
para = open("./roberta+rbt6+bert+macbert/yaclc-fluency_testB_roberta_bert_rbt6_macbert.para","r").readlines()
src = []
tgt = []
# n = 0
for line in para :
    line=line.split()
    src.append(' '.join(line[1]))
    # print(line[1])
    tgt.append(' '.join(line[2]))
    

s = open("./roberta+rbt6+bert+macbert/yaclc-fluency_testB.src","w")
[s.write(str(item)+'\n') for item in src]
s.close()

t = open("./roberta+rbt6+bert+macbert/yaclc-fluency_testB.tgt","w")
[t.write(str(item)+'\n')for item in tgt]
t.close()

# %%
# yaclc-fluency_testB ensemble
# !python ../ensemble.py \
--source_file ./roberta/yaclc-fluency_testB.src \
--target_files ./roberta/yaclc-fluency_testB.tgt ./bert/yaclc-fluency_testB.tgt ./roberta_large_19/yaclc-fluency_testB.tgt  \
--output_file yaclc-fluency_testB.preds

para = []
s = open("./roberta/yaclc-fluency_testB.src","r").readlines()
t = open("./yaclc-fluency_testB.preds","r").readlines()
output = open("./yaclc-fluency_testB.para","w")
for line in range(len(s)):
    s[line]=''.join(s[line].split())
    s[line]=s[line].lstrip(str(line))
    t[line]=''.join(t[line].split())
    t[line]=t[line].lstrip(str(line))
    para.append(str(line)+"\t"+s[line].strip("\n")+"\t"+t[line].strip("\n")+"\n")
    
    
[output.write(str(item)) for item in para]
output.close()
# Out:
# 2022-08-25 21:05:51.478741: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer.so.6'; dlerror: libnvinfer.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-08-25 21:05:51.478850: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'libnvinfer_plugin.so.6'; dlerror: libnvinfer_plugin.so.6: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2022-08-25 21:05:51.478869: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:30] Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
